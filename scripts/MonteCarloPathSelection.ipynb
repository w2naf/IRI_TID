# %% [markdown]
# # Amateur Radio Path Monte Carlo Selection
# *Nathaniel A. Frissell, W2NAF, 19 November 2024*
#
# The purpose of this notebook is to
# 1. Identify all possible transmit-receive paths from a given day's observations of actual transmitters and receivers reported to WSPRNet, PSKReporter, and RBN.
# 2. Filter those possible transmit-receive paths by a frequency range and geographic region of interest.
# 3. Randomly select a portion of those paths for ray-trace modeling.
# 4. Output results into CSVs that can be used to run the ray trace modeling.

# %%
import os
import datetime
import pickle
import bz2

import numpy as np
import pandas as pd
import geopandas as gpd

import matplotlib as mpl
import matplotlib.pyplot as plt

# from tqdm.notebook import tqdm
import tqdm

import cartopy
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# Geographiclib - https://geographiclib.sourceforge.io/Python/2.0/
# conda install conda-forge::geographiclib
from geographiclib.geodesic import Geodesic
geod = Geodesic.WGS84

# %%
plt.rcParams['font.size']      = 18
plt.rcParams['font.weight']    = 'bold'
plt.rcParams['axes.titleweight']    = 'bold'
plt.rcParams['axes.grid']      = True
plt.rcParams['axes.xmargin']   = 0
plt.rcParams['grid.linestyle'] = ':'

# %%
region_dct = {}
region_dct['World'] = tmp = {}
tmp['xlim'] = (-180, 180)
tmp['ylim'] = ( -90,  90)

# Continental US (CONUS)
region_dct['CONUS'] = tmp = {}
tmp['xlim'] = (-130,-56)
tmp['ylim'] = (  20, 55)

# CONUS + Canada
region_dct['CONUSCanada'] = tmp = {}
tmp['xlim'] = (-130, -56)
tmp['ylim'] = (  20,  80)

# %%
date   = datetime.datetime(2018,12,15)
frange = (14.000e6,14.350e6)

# %% [markdown]
# # Load Data

# %%
ham_dir   = 'ham_data'
ham_bname = '{!s}_{!s}-{!s}kHz'.format(date.strftime('%Y%m%d'),int(frange[0]/1e3),int(frange[1]/1e3))
ham_fname = f'{ham_bname}_hamSpot.pkl.bz2'
ham_fpath = os.path.join(ham_dir,ham_fname)
print(ham_fpath)
# Out:
# ham_data/20181215_14000-14350kHz_hamSpot.pkl.bz2

# %%
# Load the compressed data from the file
with open(ham_fpath, "rb") as f:
    compressed_data = f.read()

# Decompress the data
pickled_data = bz2.decompress(compressed_data)

# Unpickle the data
df = pickle.loads(pickled_data)

del compressed_data
del pickled_data

# %%
df
# Out:
#                         date call_sign_tx    txlat     txlon call_sign_rx  \
# 7        2018-12-15 00:00:00        N8MDP  41.3958  -81.2083         KN3A
# 33       2018-12-15 00:00:00        W1JGM  41.4375  -73.5417        N6PAA
# 38       2018-12-15 00:00:00         W0PE  33.8919 -117.7835         N7BT
# 53       2018-12-15 00:00:00         RQ0C  48.5208  135.0417       JK1JAS
# 54       2018-12-15 00:00:00         RQ0C  48.5208  135.0417        BG8FT
# ...                      ...          ...      ...       ...          ...
# 10101657 2018-12-15 23:59:59       YB1RUS  -6.1875  106.7083       JE2UFF
# 10101658 2018-12-15 23:59:59       YB1RUS  -6.1875  106.7083       JA1AZR
# 10101693 2018-12-15 23:59:59        W2HTS  40.2999  -74.0707         W9HM
# 10101775 2018-12-15 23:59:59        LU1XU -54.8021  -68.3042       LU3XCC
# 10101972 2018-12-15 23:59:59         N1IX  42.8604  -71.0292         W9HM
#
#             rxlat     rxlon       tfreq    sn  smode ssrc  pthlen   latcen  \
# 7         40.0625  -76.4583  14075455.0 -18.0  'FT8'  PSK   426.8  40.7535
# 33        38.2313 -121.5792  14075301.0 -18.0  'FT8'  PSK  4064.5  42.4027
# 38        48.8125 -122.5417  14075574.0 -20.0  'FT8'  PSK  1705.1  41.3764
# 53        35.3542  139.5417  14074632.0  -9.0  'FT8'  PSK  1509.9  41.9592
# 54        30.5625  103.5417  14074732.0 -16.0  'FT8'  PSK  3320.4  40.6026
# ...           ...       ...         ...   ...    ...  ...     ...      ...
# 10101657  34.8542  138.1250  14076053.0  -9.0  'FT8'  PSK  5627.3  14.8601
# 10101658  36.6458  140.7083  14076055.0  -4.0  'FT8'  PSK  5931.9  15.8826
# 10101693  44.2813  -88.3792  14074407.0  -6.0  'FT8'  PSK  1255.4  42.5133
# 10101775 -51.6354  -69.2292  14074983.0 -16.0  'FT8'  PSK   357.5 -53.2196
# 10101972  44.2813  -88.3792  14074130.0 -14.0  'FT8'  PSK  1404.0  43.9001
#
#             loncen
# 7         -78.8095
# 33        -98.1565
# 38       -119.8882
# 53        137.5251
# 54        117.1847
# ...            ...
# 10101657  120.8759
# 10101658  121.8385
# 10101693  -80.9975
# 10101775  -68.7838
# 10101972  -79.6010
#
# [2422377 rows x 14 columns]

# %% [markdown]
# # Unique TX and RX

# %%
# Unique Transmitters
tx_df = df[['call_sign_tx','txlat','txlon']].drop_duplicates('call_sign_tx').copy()

# Unique Receivers
rx_df = df[['call_sign_rx','rxlat','rxlon']].drop_duplicates('call_sign_rx').copy()

# %%
len(tx_df)
# Out:
# 15328

# %% [markdown]
# # Maps

# %%
fig     = plt.figure(figsize=(15,8))
ax      = fig.add_subplot(111,projection=ccrs.PlateCarree())
ax.add_feature(cartopy.feature.COASTLINE)
ax.add_feature(cartopy.feature.BORDERS, linestyle=':')
ax.set_title('')
ax.gridlines(draw_labels=True)

# Transmitters
xx = tx_df['txlon']
yy = tx_df['txlat']
ax.scatter(xx,yy,marker='.',color='r',label=f'TX N={len(xx)}')

# Receivers
xx = rx_df['rxlon']
yy = rx_df['rxlat']
ax.scatter(xx,yy,marker='.',color='b',alpha=0.3,label=f'RX N={len(xx)}')

ax.legend(loc='lower right',prop={'size':'x-small','weight':'normal'},framealpha=1)

region = 'World'
rdct = region_dct.get(region,region_dct['World'])
ax.set_xlim(rdct['xlim'])
ax.set_ylim(rdct['ylim'])

title = []
title.append('Amateur Radio Spot Data')
date_str = date.strftime('%Y %b %d')
f_str    = '{:0.3f} - {:0.3f} MHz'.format(frange[0]/1e6,frange[1]/1e6)
title.append(f'{date_str}; {f_str}')
ax.set_title('\n'.join(title))

plt.tight_layout()
plt.show()

# %%
paths = len(tx_df) * len(rx_df)
print(f'Theoretical TX-RX Paths: {paths:,}')
print()

hrs      = 12
dt_min   = 10
n_steps  = int((hrs*60) / dt_min)
n_traces = n_steps * paths
print('Simulation Calculator')
print(f'  Duration [hr]:  {hrs}')
print(f'  Cadence  [min]: {dt_min}')
print(f'  N Time Steps:   {n_steps}')
print(f'  N Traces:       {n_traces:,}')
# Out:
# Theoretical TX-RX Paths: 104,736,224
#
# Simulation Calculator
#   Duration [hr]:  12
#   Cadence  [min]: 10
#   N Time Steps:   72
#   N Traces:       7,541,008,128

# %% [markdown]
# # TX-RX Combinatorics

# %%
# Make dataframe of all possible TX-RX paths.
tic = datetime.datetime.now()
df_paths = []
for rx_rinx, rx_row in tqdm.tqdm(rx_df.iterrows(),total=len(rx_df)):
    df_tmp = tx_df.copy()
    df_tmp.loc[:,'call_sign_rx'] = rx_row['call_sign_rx']
    df_tmp.loc[:,'rxlat']        = rx_row['rxlat']
    df_tmp.loc[:,'rxlon']        = rx_row['rxlon']
    df_paths.append(df_tmp)

df_paths = pd.concat(df_paths,ignore_index=True)
toc = datetime.datetime.now()
print(toc-tic)
print(len(df_paths))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 6833/6833 [00:02<00:00, 3353.76it/s]
# 0:00:03.411935
# 104736224

# %% [markdown]
# # Compute Midpoints, Ranges, and Azimuths

# %%
def haversine(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # Radius of Earth in kilometers (use 3956 for miles)
    r = 6371
    return c * r

def midpoint(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Calculate midpoint
    Bx = np.cos(lat2) * np.cos(lon2 - lon1)
    By = np.cos(lat2) * np.sin(lon2 - lon1)
    lat_mid = np.arctan2(np.sin(lat1) + np.sin(lat2), np.sqrt((np.cos(lat1) + Bx) ** 2 + By ** 2))
    lon_mid = lon1 + np.arctan2(By, np.cos(lat1) + Bx)

    # Convert from radians to degrees
    lat_mid = np.degrees(lat_mid)
    lon_mid = np.degrees(lon_mid)
    
    # Convert longitudes from (0, 360) to (-180, 180)
    tf = lon_mid > 180
    lon_mid[tf] = lon_mid[tf]-360

    tf = lon_mid < -180
    lon_mid[tf] = lon_mid[tf]+360
    
    return lat_mid, lon_mid

def calc_azimuth(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    dlon = lon2 - lon1
    x = np.sin(dlon) * np.cos(lat2)
    y = np.cos(lat1) * np.sin(lat2) - np.sin(lat1) * np.cos(lat2) * np.cos(dlon)
    
    initial_bearing = np.arctan2(x, y)
    
    # Convert from radians to degrees and normalize to 0-360
    azimuth_deg = (np.degrees(initial_bearing) + 360) % 360
    return azimuth_deg

# %%
tic = datetime.datetime.now()

# %%
# distance = haversine(lat1, lon1, lat2, lon2)
df_paths['pthlen'] = haversine(df_paths['txlat'], df_paths['txlon'], df_paths['rxlat'], df_paths['rxlon'])

# %%
# mid_lat, mid_lon = midpoint(lat1, lon1, lat2, lon2)
df_paths['latcen'], df_paths['loncen'] = midpoint(df_paths['txlat'], df_paths['txlon'], df_paths['rxlat'], df_paths['rxlon'])

# %%
# azimuth = calc_azimuth(lat1, lon1, lat2, lon2)
df_paths['azm'] = calc_azimuth(df_paths['txlat'], df_paths['txlon'], df_paths['rxlat'], df_paths['rxlon'])

# %%
toc = datetime.datetime.now()
print(toc-tic)
# Out:
# 0:00:23.675201

# %% [markdown]
# # Path Selection

# %%
# Make copy of dataframe with all paths.
df_paths_0 = df_paths.copy()

# %%
df_paths = df_paths_0.copy()

# Select only paths with great circle distances <= 3000 km.
max_path = 3000
tf = df_paths['pthlen'] <= max_path
df_paths = df_paths[tf]

# Select only paths with Continental US Midpoints
region_select   = 'CONUS'
rgd             = region_dct[region_select]
lon_0, lon_1    = rgd['xlim']
lat_0, lat_1    = rgd['ylim']

tf = np.logical_and(df_paths['loncen'] >= lon_0, df_paths['loncen'] < lon_1)
df_paths = df_paths[tf]

tf = np.logical_and(df_paths['latcen'] >= lat_0, df_paths['latcen'] < lat_1)
df_paths = df_paths[tf]

# Make sure selected df_paths is an independent object in memory.
df_paths = df_paths.copy()

df_paths.sort_values(by=['call_sign_tx','call_sign_rx'],inplace=True)

# Reset index of selected paths.
df_paths.index = range(len(df_paths))

# %% [markdown]
# # Sanitize Call Signs

# %%
def saniztize_calls(df):
    """
    Replace characters in call signs that cause trouble with the linux file system
    (like '/') with and underscore.
    """
    df['call_sign_tx'] = df['call_sign_tx'].apply(lambda x: x.replace('/','_'))
    df['call_sign_rx'] = df['call_sign_rx'].apply(lambda x: x.replace('/','_'))
    return df

# %%
df_paths = saniztize_calls(df_paths)

# %%
df_paths
# Out:
#          call_sign_tx      txlat      txlon call_sign_rx    rxlat    rxlon  \
# 0              1N8KHW  36.145833 -95.958333        AA0RR  41.3604 -93.5625
# 1              1N8KHW  36.145833 -95.958333        AA1SU  44.4896 -73.1125
# 2              1N8KHW  36.145833 -95.958333        AA2AD  41.9188 -79.6292
# 3              1N8KHW  36.145833 -95.958333        AA2AE  43.1875 -76.3750
# 4              1N8KHW  36.145833 -95.958333        AA2CC  42.7604 -78.7375
# ...               ...        ...        ...          ...      ...      ...
# 11231551       YY7WGA  10.979200 -63.958300       WD4JJI  28.9104 -81.9875
# 11231552       YY7WGA  10.979200 -63.958300       WD4MTK  34.2104 -77.9125
# 11231553       YY7WGA  10.979200 -63.958300         WH6A  29.0625 -81.0417
# 11231554       YY7WGA  10.979200 -63.958300        WW1TA  32.8813 -79.7875
# 11231555       YY7WGA  10.979200 -63.958300         WW3A  29.0813 -81.3458
#
#                pthlen     latcen     loncen         azm
# 0          615.856522  38.759222 -94.804209   18.970957
# 1         2137.881952  40.881897 -85.251956   57.254777
# 2         1546.292255  39.317670 -88.129787   60.514860
# 3         1844.119407  40.079249 -86.671153   58.892027
# 4         1647.135780  39.771378 -87.760503   58.231930
# ...               ...        ...        ...         ...
# 11231551  2735.463262  20.173463 -72.452517  319.396478
# 11231552  2946.267226  22.745140 -70.335618  333.449015
# 11231553  2681.178176  20.226596 -72.001028  321.057619
# 11231554  2923.374004  22.119725 -71.252404  328.856568
# 11231555  2703.612261  20.243528 -72.143263  320.633258
#
# [11231556 rows x 10 columns]

# %% [markdown]
# # Monte Carlo Selection

# %%
N_samples = 3000
seed      = np.random.randint(0,2**63-1)

rng       = np.random.default_rng(seed)
randInxs  = rng.integers(0,len(df_paths),N_samples)
df_monte  = df_paths.iloc[randInxs].copy()
df_monte.sort_values(by=['call_sign_tx','call_sign_rx'],inplace=True)

# %% [markdown]
# # Midpoint Maps

# %%
fig     = plt.figure(figsize=(15,8))
ax      = fig.add_subplot(111,projection=ccrs.PlateCarree())
ax.add_feature(cartopy.feature.COASTLINE)
ax.add_feature(cartopy.feature.BORDERS, linestyle=':')
ax.set_title('')
ax.gridlines(draw_labels=True)

# Midpoints
xx = df_paths['loncen']
yy = df_paths['latcen']
ax.scatter(xx,yy,marker='.',color='g',label=f'All Paths N={len(xx):,}')

# Midpoints
xx = df_monte['loncen']
yy = df_monte['latcen']
ax.scatter(xx,yy,marker='.',color='b',label=f'Monte Carlo N={len(xx):,}')

ax.legend(loc='lower right',prop={'size':'x-small','weight':'normal'},framealpha=1)
    
region = 'World'
rdct = region_dct.get(region,region_dct['World'])
ax.set_xlim(rdct['xlim'])
ax.set_ylim(rdct['ylim'])

title = []
title.append('Amateur Radio Spot Data')
date_str = date.strftime('%Y %b %d')
f_str    = '{:0.3f} - {:0.3f} MHz'.format(frange[0]/1e6,frange[1]/1e6)
title.append(f'{date_str}; {f_str}')
ax.set_title('\n'.join(title))

plt.tight_layout()
plt.show()

# %% [markdown]
# # Midpoint Heatmaps

# %%
def plot_heatmap(df_paths, region='CONUS', label = ''):
    dlat = 1
    dlon = 1
    lat_bins = np.arange(-90,90+dlat,dlat)
    lon_bins = np.arange(-180,180+dlat,dlat)
    bins     = (lon_bins, lat_bins)
    
    xx = df_paths['loncen']
    yy = df_paths['latcen']
    heatmap, LON_BINS, LAT_BINS = np.histogram2d(xx,yy,bins=bins)
    
    fig     = plt.figure(figsize=(15,8))
    ax      = fig.add_subplot(111,projection=ccrs.PlateCarree())
    ax.add_feature(cartopy.feature.COASTLINE)
    ax.add_feature(cartopy.feature.BORDERS, linestyle=':')
    ax.set_title('')
    ax.gridlines(draw_labels=True)
    
    # Midpoints
    xx   = lon_bins
    yy   = lat_bins
    zz   = heatmap
    mpbl = ax.pcolormesh(xx,yy,zz.T)
    plt.colorbar(mpbl,label='N Midpoints',shrink=0.65,pad=0.075)
    
    txt  = f'{label} N = {len(df_paths):,}'
    ax.text(0.98,0.05,txt,transform=ax.transAxes,bbox={'facecolor':'white'},ha='right')

    rdct = region_dct.get(region,region_dct['World'])
    ax.set_xlim(rdct['xlim'])
    ax.set_ylim(rdct['ylim'])
    
    title = []
    title.append('Amateur Radio Spot Data')
    date_str = date.strftime('%Y %b %d')
    f_str    = '{:0.3f} - {:0.3f} MHz'.format(frange[0]/1e6,frange[1]/1e6)
    title.append(f'{date_str}; {f_str}')
    ax.set_title('\n'.join(title))
    
    plt.tight_layout()
    plt.show()

# %%
plot_heatmap(df_paths,label='All Paths')

# %%
plot_heatmap(df_monte,label='Monte Carlo')

# %% [markdown]
# # Range and Azimuth Distrbutions

# %%
def plot_hists(df_paths,title=None):
    drange = 25
    bins   = np.arange(0,max_path+drange,drange)
    hist, range_bins = np.histogram(df_paths['pthlen'],bins=bins)
    
    dazm  = 15
    bins  = np.arange(0,360+dazm,dazm)
    azm_hist, azm_bins = np.histogram(df_paths['azm'],bins=bins)

    fig = plt.figure(figsize=(12,5))
    ax  = fig.add_subplot(1,2,1)
    plt.bar(range_bins[:-1],hist,width=drange)
    plt.xlabel('Ground Range [km]')
    plt.ylabel('N Paths')
    plt.title(title)
    
    ax  = fig.add_subplot(1,2,2)
    plt.bar(azm_bins[:-1],azm_hist,width=dazm)
    plt.xlabel('Azimuth [deg]')
    plt.ylabel('N Paths')
    plt.title(title)

    plt.tight_layout()
    plt.show()

plot_hists(df_paths,title='All Paths')

# %%
plot_hists(df_monte,title='Monte Carlo')

# %% [markdown]
# # Output CSV

# %% [raw]
# # Don't run this cell unless you really need to...
# # The resulting all Possible Radio Paths csv file is about 1.3 GB.
# header = []
# header.append('# All Possible Amateur Radio Paths - WSPRNet, PSKReporter, RBN')
# header.append(f'# Source File: {ham_fpath}')
# header.append('#')
# header.append('# Date: {}'.format(date.strftime('%d %B %Y')))
# header.append('# Frequency Range: {:0.3f} - {:0.3f} MHz'.format(frange[0]/1e6, frange[1]/1e6))
# header.append('#')
# header.append(f'# Region: {region_select}')
# header.append(f'#   Lat Limits: {region_dct[region_select]['ylim']}')
# header.append(f'#   Lon Limits: {region_dct[region_select]['xlim']}')
# header.append('#\n')
#
# fname    = f'{ham_bname}_allPaths.csv'
# with open(fname, 'w') as fl:
#     fl.write('\n'.join(header))
#
# with open(fname, 'a') as fl:
#     df_paths.to_csv(fl,index=False)

# %%
header = []
header.append('# Monte Carlo Subset of Amateur Radio Paths')
header.append(f'# Source File: {ham_fpath}')
header.append('#')
header.append('# Date: {}'.format(date.strftime('%d %B %Y')))
header.append('# Frequency Range: {:0.3f} - {:0.3f} MHz'.format(frange[0]/1e6, frange[1]/1e6))
header.append('#')
header.append(f'# Region: {region_select}')
header.append(f'#   Lat Limits: {region_dct[region_select]['ylim']}')
header.append(f'#   Lon Limits: {region_dct[region_select]['xlim']}')
header.append('#')
header.append(f'# N Paths: {N_samples}')
header.append(f'# np.random.default_rng() seed: {seed}')
header.append('#\n')

fname    = f'{ham_bname}_montePaths.csv'
with open(fname, 'w') as fl:
    fl.write('\n'.join(header))

with open(fname, 'a') as fl:
    df_monte.to_csv(fl,index=False)
